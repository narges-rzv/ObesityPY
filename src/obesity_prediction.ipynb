# %%
import pickle
import train

# %%
d1 = pickle.load(open('patientdata_20170823.pkl', 'rb'))
d1mom = pickle.load(open('patient_mother_data_20170724.pkl', 'rb'))

# %%
import importlib as imp
import build_features
imp.reload(build_features)
import train
imp.reload(train)
(model, xtrain, ytrain, xtest, ytest, ytestlabel, ytrainlabel, auc_test, r2test, feature_headers, centroids, hnew, standardDevCentroids, cnt_clusters, distances, muxnew, stdxnew, mrnstrain, mrnstest, mrngirls) = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 24, filterSTR=['Gender:1', 'Vital: Wt-avg0to1', 'Vital: Wt-avg1to3','Vital: BMI-avg10to13','Vital: BMI-avg19to24' ,'Vital: BMI-avg0to1', 'Vital: BMI-avg1to3', 'Vital: Wt-avg10to13','Vital: Wt-avg19to24'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=True, add_time=False, do_impute=False, do_normalize=False)
(model, xtrain, ytrain, xtest, ytest, ytestlabel, ytrainlabel, auc_test, r2test, feature_headers, centroids, hnew, standardDevCentroids, cnt_clusters, distances, muxnew, stdxnew, mrnstrain, mrnstest, mrnboys) = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 24, filterSTR=['Gender:0', 'Vital: Wt-avg0to1', 'Vital: Wt-avg1to3','Vital: BMI-avg10to13','Vital: BMI-avg19to24' ,'Vital: BMI-avg0to1', 'Vital: BMI-avg1to3', 'Vital: Wt-avg10to13','Vital: Wt-avg19to24'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=True, add_time=False, do_impute=False, do_normalize=False)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1051 patients selected..
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.474  min: 11.2275  max: 35.0625
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-24 months
# filtering patients with:  ['Gender:1', 'Vital: Wt-avg0to1', 'Vital: Wt-avg1to3', 'Vital: BMI-avg10to13', 'Vital: BMI-avg19to24', 'Vital: BMI-avg0to1', 'Vital: BMI-avg1to3', 'Vital: Wt-avg10to13', 'Vital: Wt-avg19to24']
# total size 1051
# ...

# %%
import importlib as imp
import build_features
imp.reload(build_features)
import train
imp.reload(train)
# Out:
# <module 'train' from '/Users/Narges/git/ObesityPY/src/train.py'>

# %%
outgirls24 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 24,filterSTR=['Gender:1'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrngirls)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1051 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.474  min: 11.2275  max: 35.0625
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-24 months
# filtering patients with:  ['Gender:1']
# ...

# %%
outgirls18 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 18,filterSTR=['Gender:1'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrngirls)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1051 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.474  min: 11.2275  max: 35.0625
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-18 months
# filtering patients with:  ['Gender:1']
# ...

# %%
outgirls12 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 12,filterSTR=['Gender:1'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrngirls)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1051 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.474  min: 11.2275  max: 35.0625
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-12 months
# filtering patients with:  ['Gender:1']
# ...

# %%
outgirls6 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 6,filterSTR=['Gender:1'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrngirls)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1051 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.474  min: 11.2275  max: 35.0625
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-6 months
# filtering patients with:  ['Gender:1']
# ...

# %%
outboys24 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 24, filterSTR=['Gender:0'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrnboys)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1060 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.927  min: 11.915  max: 38.514
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-24 months
# filtering patients with:  ['Gender:0']
# ...

# %%
outboys18 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 18, filterSTR=['Gender:0'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrnboys)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1060 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.927  min: 11.915  max: 38.514
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-18 months
# filtering patients with:  ['Gender:0']
# ...

# %%
outboys12 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 12, filterSTR=['Gender:0'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrnboys)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1060 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.927  min: 11.915  max: 38.514
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-12 months
# filtering patients with:  ['Gender:0']
# ...

# %%
outboys6 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 6, filterSTR=['Gender:0'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrnboys)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1060 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.927  min: 11.915  max: 38.514
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-6 months
# filtering patients with:  ['Gender:0']
# ...

# %%
# from pyglmnet import GLM
# import numpy as np
# print(xtrain.shape)
# import matplotlib.pylab as plt
# cov = np.matmul(xtrain.transpose(), xtrain)
# print(cov.shape)
# plt.imshow([np.array([[1,1],[1,1]])]); plt.colorbar(); plt.show()

# %%
# gl_glm = GLM(distr="binomial",
#              tol=1e-2,
#              group=group_idxs,
#              score_metric="pseudo_R2",
#              alpha=1.0,
#              reg_lambda=np.logspace(np.log(100), np.log(0.01), 5, base=np.exp(1)))

# %%
imp.reload(train)
outboys6 = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 6, filterSTR=['Gender:0'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lasso', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrnboys)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1060 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.927  min: 11.915  max: 38.514
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-6 months
# filtering patients with:  ['Gender:0']
# ...

# %%
outboys6_lars = train.train_regression_model_for_bmi(d1, d1mom, 4.5, 5.5, 0, 6, filterSTR=['Gender:0'], variablesubset=[], num_clusters=16, num_iters=100, dist_type='euclidean', modelType='lars', return_data_for_error_analysis=False, add_time=False, do_impute=False, mrnForFilter=mrnboys)
# Out:
# 6411 features are binary
# x shape: (52945, 6562) num features: 6562
# 1060 patients selected..
# /Users/Narges/git/ObesityPY/src/train.py:154: RuntimeWarning: Mean of empty slice
#   mu = np.nanmean(xcop, axis=0)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Narges/anaconda2/envs/3point5/lib/python3.5/site-packages/numpy/lib/function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 6412
# corr matrix is filtered to size (6562, 6412)
# output is: average:16.927  min: 11.915  max: 38.514
# normalizing output.
# Predicting BMI at age:4.5 to 5.5years, from data in ages:0-6 months
# filtering patients with:  ['Gender:0']
# ...
